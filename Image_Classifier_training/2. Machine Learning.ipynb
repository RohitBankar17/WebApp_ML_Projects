# %%
import os
import re
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [raw]
# !conda install -c conda-forge scikit-image

# %%
import skimage
import skimage.color
import skimage.io
import skimage.feature
import skimage.transform

# %%
skimage.__version__
# Out:
# '0.16.2'

# %%
# load the data
data = pickle.load(open('data_animals_head_20.pickle','rb'))

# %%
data['description']
# Out:
# 'There are 20 classes and 2057 images are there. All the images are 80 x 80 (rgb)'

# %%
# split the data into independent and dependent
X = data['data'] # independent
y = data['target'] # dependent

# %%
print(X)
# Out:
# [[[[196 214 188]
#    [196 214 188]
#    [196 215 187]
#    ...
#    [ 81  76  80]
#    [ 81  76  80]
#    [ 69  64  68]]
#
#   [[196 214 188]
#    [196 214 188]
#    [196 215 187]
#    ...
#    [ 82  77  81]
#    [ 83  78  82]
#    [ 77  72  76]]
#
#   [[193 213 185]
#    [194 214 186]
#    [194 214 186]
#    ...
#    [ 82  77  81]
#    [ 82  76  80]
#    [ 79  73  77]]
#
#   ...
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 70  65  69]
#    [ 65  60  66]
#    [ 62  57  63]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 66  61  65]
#    [ 62  57  63]
#    [ 64  59  65]]
#
#   [[254 254 254]
#    [254 254 254]
#    [254 254 254]
#    ...
#    [ 56  51  55]
#    [ 79  74  80]
#    [ 69  64  70]]]
#
#
#  [[[  4   2   3]
#    [  7   5   6]
#    [  6   5   3]
#    ...
#    [ 42  31  25]
#    [ 46  35  29]
#    [ 43  32  26]]
#
#   [[  7   5   6]
#    [  5   3   4]
#    [  2   1   0]
#    ...
#    [ 21  12   5]
#    [ 43  32  26]
#    [ 46  37  30]]
#
#   [[  6   5   3]
#    [  3   2   0]
#    [  2   1   0]
#    ...
#    [ 32  25  17]
#    [ 48  39  32]
#    [ 53  46  38]]
#
#   ...
#
#   [[ 24  30   4]
#    [ 24  30   4]
#    [ 25  31   5]
#    ...
#    [116 116  80]
#    [115 117  80]
#    [127 129  92]]
#
#   [[ 22  27   4]
#    [ 23  28   5]
#    [ 24  29   6]
#    ...
#    [112 112  76]
#    [115 117  80]
#    [128 130  93]]
#
#   [[ 22  27   4]
#    [ 22  27   4]
#    [ 22  27   4]
#    ...
#    [106 106  70]
#    [112 114  77]
#    [126 128  91]]]
#
#
#  [[[104 109 102]
#    [105 110 103]
#    [108 115 107]
#    ...
#    [130 126 127]
#    [122 117 121]
#    [123 118 122]]
#
#   [[113 118 111]
#    [ 98 103  96]
#    [103 110 102]
#    ...
#    [111 107 108]
#    [129 124 128]
#    [150 145 149]]
#
#   [[126 133 125]
#    [112 119 111]
#    [110 117 109]
#    ...
#    [137 135 136]
#    [160 158 161]
#    [161 159 162]]
#
#   ...
#
#   [[214 214 202]
#    [206 206 194]
#    [203 199 187]
#    ...
#    [164 162 150]
#    [173 173 163]
#    [187 187 179]]
#
#   [[219 219 207]
#    [210 210 198]
#    [206 202 190]
#    ...
#    [170 168 156]
#    [174 174 164]
#    [188 188 180]]
#
#   [[214 214 202]
#    [201 201 189]
#    [199 195 183]
#    ...
#    [172 170 158]
#    [179 179 169]
#    [184 184 176]]]
#
#
#  ...
#
#
#  [[[147 154 113]
#    [145 152 111]
#    [146 153 112]
#    ...
#    [102 109  57]
#    [118 122  72]
#    [128 131  84]]
#
#   [[148 155 114]
#    [146 153 112]
#    [145 152 111]
#    ...
#    [120 128  71]
#    [138 142  91]
#    [151 155 104]]
#
#   [[147 154 112]
#    [146 153 111]
#    [144 151 109]
#    ...
#    [136 142  80]
#    [143 151  92]
#    [150 158  99]]
#
#   ...
#
#   [[137 141  90]
#    [146 150  99]
#    [145 148 101]
#    ...
#    [145 137 100]
#    [150 142 103]
#    [158 150 111]]
#
#   [[133 138  84]
#    [128 133  79]
#    [129 133  83]
#    ...
#    [158 153 115]
#    [157 152 112]
#    [154 149 109]]
#
#   [[130 135  79]
#    [128 133  79]
#    [135 139  88]
#    ...
#    [160 155 117]
#    [157 152 112]
#    [150 145 105]]]
#
#
#  [[[246 250 249]
#    [247 251 250]
#    [252 254 251]
#    ...
#    [136 118 114]
#    [142 125 118]
#    [144 127 120]]
#
#   [[244 248 247]
#    [252 255 255]
#    [243 245 242]
#    ...
#    [139 124 119]
#    [135 120 113]
#    [156 141 134]]
#
#   [[238 242 241]
#    [248 252 251]
#    [246 248 247]
#    ...
#    [127 118 109]
#    [128 118 109]
#    [141 131 122]]
#
#   ...
#
#   [[237 233 224]
#    [230 226 217]
#    [228 224 215]
#    ...
#    [159 142 126]
#    [152 135 119]
#    [150 133 115]]
#
#   [[234 231 222]
#    [233 230 221]
#    [229 225 216]
#    ...
#    [185 169 153]
#    [165 149 133]
#    [169 153 137]]
#
#   [[242 239 230]
#    [236 233 224]
#    [229 225 216]
#    ...
#    [193 177 161]
#    [185 169 154]
#    [175 159 144]]]
#
#
#  [[[ 85  78  32]
#    [ 79  72  26]
#    [ 79  72  26]
#    ...
#    [ 80  73  27]
#    [ 76  69  23]
#    [ 74  67  21]]
#
#   [[ 84  77  31]
#    [ 79  72  26]
#    [ 78  71  25]
#    ...
#    [ 78  71  25]
#    [ 75  68  22]
#    [ 71  64  18]]
#
#   [[ 81  77  30]
#    [ 78  74  27]
#    [ 77  70  24]
#    ...
#    [ 78  71  27]
#    [ 76  69  25]
#    [ 71  64  20]]
#
#   ...
#
#   [[ 85  55  17]
#    [ 90  60  22]
#    [ 90  58  20]
#    ...
#    [103 101  53]
#    [100  96  49]
#    [ 96  94  46]]
#
#   [[ 87  58  18]
#    [ 80  51  11]
#    [ 88  56  17]
#    ...
#    [104 100  53]
#    [103  96  50]
#    [ 98  94  47]]
#
#   [[ 82  53  13]
#    [ 81  52  12]
#    [ 92  60  21]
#    ...
#    [101  94  48]
#    [100  93  47]
#    [ 98  91  45]]]]

# %%
print(y)
# Out:
# ['bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'bear', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'chicken', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'cow', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', 'deer', ' ...

# %%
# split the data into train and test
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,stratify=y)

# %%
x_train.shape,x_test.shape,len(y_train),len(y_test)
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3), 1645, 412)

# %% [markdown]
# ---
# ####  Feature Extraction
# - Hog
# [URL](https://www.analyticsvidhya.com/blog/2019/09/feature-engineering-images-introduction-hog-feature-descriptor/#:~:text=HOG%2C%20or%20Histogram%20of%20Oriented,vision%20tasks%20for%20object%20detection.)

# %%
ls images
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is FAA9-24C8
#
#  Directory of D:\Image classifier\images
#
# 26-05-2021  09:36    <DIR>          .
# 26-05-2021  09:36    <DIR>          ..
# 21-02-2021  18:51            35,167 astro_gray.jpg
# 21-02-2021  16:01            40,344 astronaut.jpg
# 21-02-2021  16:02            41,686 coffee.jpg
# 21-02-2021  16:03             8,344 colorwheel.jpg
# 07-02-2021  14:15            51,426 dog_test.jpg
# 07-02-2021  14:08            98,479 eagle.jpg
# 21-02-2021  19:07             3,428 landscape.jpg
# 21-02-2021  19:17             8,844 landscape_hist_eq.jpg
# 02-02-2021  21:41           122,337 lion.bmp
# 21-02-2021  16:01            28,644 rocket.jpg
#               10 File(s)        438,699 bytes
#                2 Dir(s)  286,268,219,392 bytes free

# %%
img = skimage.io.imread('./images/lion.bmp')
plt.figure(figsize=(6,10))
plt.imshow(img)

# %%
# hog transoform
img_re = skimage.transform.rescale(img,1/3).reshape((302,215))
gray = skimage.color.rgb2gray(img_re)
feature_vector, hog_img = skimage.feature.hog(gray,orientations=9,
                    pixels_per_cell=(14,14),
                    cells_per_block=(2,2),
                    visualize=True)

# %%
len(feature_vector)
# Out:
# 10080

# %%
gray.shape
# Out:
# (302, 215)

# %%
302*215
# Out:
# 64930

# %%
plt.figure(figsize=(12,10))
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(hog_img,cmap='gray')

# %% [markdown]
# ---

# %% [markdown]
# ## Preprocessing
# - Grayscale
# - Hog (histogram oriented gradient) tranformer

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from skimage.color import rgb2gray

# %%
class rgb2gray_transform(BaseEstimator,TransformerMixin):
    import skimage.color
    def __init__(self):
        pass
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        return np.array([skimage.color.rgb2gray(x) for x in X])

# %%
x_train.shape
# Out:
# (1645, 80, 80, 3)

# %%
rgb2grayobj = rgb2gray_transform()
x_train_gray = rgb2grayobj.fit_transform(x_train)

# %%
x_train_gray.shape
# Out:
# (1645, 80, 80)

# %%
plt.subplot(1,2,1)
plt.imshow(x_train[22])
plt.subplot(1,2,2)
plt.imshow(x_train_gray[22],cmap='gray')

# %%
class hogtransformer(BaseEstimator,TransformerMixin):
    import skimage.feature
    def __init__(self,orientations=9,pixels_per_cell=(8, 8),cells_per_block=(3, 3),):
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        
        
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        def local_hog(img):
            hog_features= skimage.feature.hog(img,orientations=self.orientations,
                                pixels_per_cell=self.pixels_per_cell,
                                cells_per_block=self.cells_per_block)
            
            return hog_features
        
        hfeatures = np.array([local_hog(x) for x in X])
        return hfeatures

# %%
hogt = hogtransformer()

# %%
x_train_hog = hogt.fit_transform(x_train_gray)

# %%
x_train_hog.shape
# Out:
# (1645, 5184)

# %% [markdown]
# ### Training Machine Learning Model

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
import sklearn.metrics
from sklearn.preprocessing import StandardScaler

# %%
model_sgd = SGDClassifier(loss='hinge',learning_rate='adaptive',
                          early_stopping=True,eta0=0.1,)

# %%
x_train.shape,x_test.shape
# Out:
# ((1645, 80, 80, 3), (412, 80, 80, 3))

# %%
grayify = rgb2gray_transform()
hogify = hogtransformer()
scalify = StandardScaler()

# %%
# pipeline
# step-1: convert into grayscale
x_train_gray = grayify.fit_transform(x_train)
# step-2: extract the features
x_train_hog = hogify.fit_transform(x_train_gray)
# step-3: Normalization
x_train_scale = scalify.fit_transform(x_train_hog)
# step-4: machine learning
model_sgd.fit(x_train_scale,y_train)
# Out:
# SGDClassifier(early_stopping=True, eta0=0.1, learning_rate='adaptive')

# %%
x_test_gray = grayify.fit_transform(x_test)
# step-2: extract the features
x_test_hog = hogify.fit_transform(x_test_gray)
# step-3: Normalization
x_test_scale = scalify.transform(x_test_hog)

y_pred_test = model_sgd.predict(x_test_scale)

# %%
y_pred_test
# Out:
# array(['monkey', 'bear', 'elephant', 'panda', 'cat', 'cat', 'bear',
#        'pigeon', 'tiger', 'pigeon', 'cat', 'duck', 'chicken', 'wolf',
#        'lion', 'chicken', 'tiger', 'panda', 'sheep', 'wolf', 'lion',
#        'tiger', 'sheep', 'chicken', 'elephant', 'tiger', 'cat', 'duck',
#        'duck', 'tiger', 'bear', 'lion', 'cat', 'rabbit', 'human', 'duck',
#        'panda', 'sheep', 'tiger', 'duck', 'lion', 'deer', 'pigeon',
#        'monkey', 'dog', 'deer', 'cat', 'deer', 'cat', 'wolf', 'sheep',
#        'deer', 'monkey', 'sheep', 'duck', 'bear', 'rabbit', 'mouse',
#        'wolf', 'cat', 'pigeon', 'pigeon', 'eagle', 'chicken', 'mouse',
#        'deer', 'mouse', 'eagle', 'mouse', 'sheep', 'cat', 'duck', 'deer',
#        'elephant', 'chicken', 'eagle', 'dog', 'dog', 'panda', 'deer',
#        'panda', 'panda', 'deer', 'duck', 'cat', 'sheep', 'eagle',
#        'rabbit', 'lion', 'human', 'rabbit', 'bear', 'elephant', 'mouse',
#        'dog', 'bear', 'monkey', 'rabbit', 'pigeon', 'eagle', 'elephant',
#        'chicken', 'rabbit', 'human', 'eagle', 'chicken', 'deer', 'cat',
#        'panda', 'wolf', 'tiger', 'cat', 'bear', 'duck', 'pigeon',
#        'monkey', 'dog', 'deer', 'dog', 'eagle', 'cat', 'pigeon', 'dog',
#        'duck', 'pigeon', 'rabbit', 'panda', 'rabbit', 'human', 'chicken',
#        'duck', 'panda', 'sheep', 'rabbit', 'monkey', 'chicken', 'wolf',
#        'wolf', 'dog', 'cat', 'cow', 'pigeon', 'rabbit', 'deer', 'eagle',
#        'sheep', 'natural', 'duck', 'rabbit', 'panda', 'panda', 'elephant',
#        'rabbit', 'cat', 'monkey', 'human', 'duck', 'panda', 'wolf',
#        'elephant', 'dog', 'cow', 'human', 'dog', 'tiger', 'elephant',
#        'mouse', 'deer', 'duck', 'chicken', 'cow', 'eagle', 'cat', 'cat',
#        'monkey', 'lion', 'lion', 'human', 'wolf', 'lion', 'wolf', 'wolf',
#        'bear', 'wolf', 'lion', 'pigeon', 'natural', 'wolf', 'bear',
#        'pigeon', 'rabbit', 'panda', 'dog', 'elephant', 'eagle', 'mouse',
#        'tiger', 'sheep', 'panda', 'wolf', 'tiger', 'panda', 'panda',
#        'duck', 'duck', 'rabbit', 'dog', 'cat', 'tiger', 'cat', 'dog',
#        'chicken', 'human', 'human', 'elephant', 'elephant', 'tiger',
#        'panda', 'deer', 'mouse', 'mouse', 'elephant', 'natural', 'bear',
#        'pigeon', 'cow', 'chicken', 'mouse', 'mouse', 'rabbit', 'cat',
#        'human', 'deer', 'bear', 'monkey', 'dog', 'wolf', 'chicken', 'cow',
#        'deer', 'duck', 'monkey', 'mouse', 'duck', 'wolf', 'rabbit',
#        'panda', 'deer', 'monkey', 'human', 'cow', 'cat', 'cat', 'cow',
#        'cat', 'eagle', 'mouse', 'elephant', 'bear', 'wolf', 'duck',
#        'chicken', 'human', 'mouse', 'duck', 'monkey', 'cat', 'pigeon',
#        'monkey', 'bear', 'human', 'deer', 'human', 'monkey', 'chicken',
#        'bear', 'duck', 'bear', 'chicken', 'duck', 'duck', 'dog', 'deer',
#        'panda', 'tiger', 'cow', 'rabbit', 'rabbit', 'cat', 'cat',
#        'monkey', 'monkey', 'elephant', 'elephant', 'cow', 'mouse',
#        'pigeon', 'dog', 'pigeon', 'pigeon', 'sheep', 'deer', 'tiger',
#        'lion', 'cow', 'elephant', 'eagle', 'pigeon', 'bear', 'eagle',
#        'panda', 'panda', 'pigeon', 'wolf', 'chicken', 'cat', 'lion',
#        'monkey', 'sheep', 'monkey', 'tiger', 'pigeon', 'eagle', 'rabbit',
#        'human', 'panda', 'human', 'tiger', 'deer', 'tiger', 'sheep',
#        'mouse', 'eagle', 'tiger', 'duck', 'sheep', 'chicken', 'elephant',
#        'pigeon', 'mouse', 'rabbit', 'elephant', 'monkey', 'cat', 'cow',
#        'cat', 'elephant', 'panda', 'wolf', 'mouse', 'human', 'monkey',
#        'human', 'monkey', 'pigeon', 'cow', 'monkey', 'human', 'human',
#        'deer', 'sheep', 'elephant', 'deer', 'human', 'dog', 'cat',
#        'monkey', 'chicken', 'panda', 'duck', 'eagle', 'wolf', 'elephant',
#        'monkey', 'duck', 'cat', 'panda', 'tiger', 'pigeon', 'cow', 'duck',
#        'eagle', 'tiger', 'sheep', 'human', 'chicken', 'cow', 'lion',
#        'lion', 'deer', 'sheep', 'cat', 'lion', 'cow', 'pigeon', 'tiger',
#        'duck', 'cow', 'eagle', 'human', 'dog', 'dog', 'human', 'chicken',
#        'wolf', 'panda', 'pigeon', 'elephant', 'pigeon', 'cat', 'dog',
#        'cow'], dtype='<U8')

# %% [markdown]
# ### Model Evaluation

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred_test,output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# bear           0.687500  0.550000  0.611111   20.000000
# cat            0.575758  0.593750  0.584615   32.000000
# chicken        0.666667  0.700000  0.682927   20.000000
# cow            0.470588  0.380952  0.421053   21.000000
# deer           0.739130  0.809524  0.772727   21.000000
# dog            0.500000  0.384615  0.434783   26.000000
# duck           0.464286  0.619048  0.530612   21.000000
# eagle          0.611111  0.550000  0.578947   20.000000
# elephant       0.636364  0.700000  0.666667   20.000000
# human          0.791667  0.950000  0.863636   20.000000
# lion           0.357143  0.250000  0.294118   20.000000
# monkey         0.291667  0.350000  0.318182   20.000000
# mouse          0.388889  0.350000  0.368421   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.653846  0.708333  0.680000   24.000000
# pigeon         0.500000  0.565217  0.530612   23.000000
# rabbit         0.600000  0.600000  0.600000   20.000000
# sheep          0.647059  0.550000  0.594595   20.000000
# tiger          0.619048  0.565217  0.590909   23.000000
# wolf           0.714286  0.750000  0.731707   20.000000
# accuracy       0.572816  0.572816  0.572816    0.572816
# macro avg      0.545750  0.546333  0.542781  412.000000
# weighted avg   0.572465  0.572816  0.569285  412.000000

# %%
metrics.cohen_kappa_score(y_test,y_pred_test)
# Out:
# 0.5488639474404597

# %% [markdown]
# # Pipeline Model

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipeline = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer(orientations=8,pixels_per_cell=(10,10),cells_per_block=(3,3))),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier(loss='hinge',learning_rate='adaptive',eta0=0.001))
])

# %%
model_pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('grascale', rgb2gray_transform()),
#                 ('hogtransform',
#                  hogtransformer(orientations=8, pixels_per_cell=(10, 10))),
#                 ('scale', StandardScaler()),
#                 ('sgd', SGDClassifier(eta0=0.001, learning_rate='adaptive'))])

# %%
y_pred = model_pipeline.predict(x_test)

# %%
y_pred
# Out:
# array(['monkey', 'rabbit', 'pigeon', 'panda', 'cat', 'cat', 'mouse',
#        'pigeon', 'tiger', 'rabbit', 'cat', 'duck', 'dog', 'lion', 'bear',
#        'chicken', 'dog', 'rabbit', 'chicken', 'wolf', 'lion', 'cat',
#        'sheep', 'chicken', 'pigeon', 'tiger', 'cat', 'wolf', 'cow',
#        'lion', 'bear', 'bear', 'lion', 'rabbit', 'human', 'duck',
#        'monkey', 'sheep', 'cow', 'duck', 'lion', 'human', 'pigeon',
#        'monkey', 'elephant', 'deer', 'cat', 'deer', 'duck', 'wolf', 'dog',
#        'cow', 'wolf', 'chicken', 'duck', 'tiger', 'rabbit', 'mouse',
#        'wolf', 'tiger', 'rabbit', 'pigeon', 'eagle', 'chicken', 'mouse',
#        'deer', 'mouse', 'sheep', 'lion', 'sheep', 'cat', 'duck', 'deer',
#        'elephant', 'chicken', 'cat', 'monkey', 'lion', 'pigeon', 'deer',
#        'panda', 'panda', 'deer', 'human', 'mouse', 'rabbit', 'wolf',
#        'rabbit', 'lion', 'human', 'rabbit', 'sheep', 'elephant', 'lion',
#        'bear', 'wolf', 'mouse', 'rabbit', 'pigeon', 'sheep', 'elephant',
#        'chicken', 'eagle', 'deer', 'eagle', 'chicken', 'deer', 'cat',
#        'pigeon', 'wolf', 'wolf', 'wolf', 'dog', 'mouse', 'pigeon',
#        'monkey', 'panda', 'deer', 'dog', 'eagle', 'bear', 'deer', 'dog',
#        'elephant', 'duck', 'rabbit', 'panda', 'wolf', 'pigeon', 'mouse',
#        'eagle', 'panda', 'sheep', 'rabbit', 'mouse', 'chicken', 'duck',
#        'wolf', 'dog', 'cat', 'bear', 'dog', 'elephant', 'deer', 'chicken',
#        'human', 'elephant', 'duck', 'mouse', 'dog', 'dog', 'cat', 'cat',
#        'cat', 'dog', 'human', 'dog', 'bear', 'rabbit', 'rabbit', 'eagle',
#        'rabbit', 'human', 'dog', 'tiger', 'elephant', 'rabbit', 'cow',
#        'duck', 'duck', 'cow', 'dog', 'lion', 'sheep', 'duck', 'cow',
#        'lion', 'human', 'wolf', 'lion', 'wolf', 'wolf', 'cat', 'wolf',
#        'rabbit', 'pigeon', 'monkey', 'bear', 'bear', 'pigeon', 'rabbit',
#        'bear', 'elephant', 'elephant', 'lion', 'lion', 'tiger', 'sheep',
#        'cat', 'bear', 'pigeon', 'panda', 'panda', 'duck', 'lion', 'wolf',
#        'dog', 'wolf', 'tiger', 'cat', 'cow', 'duck', 'human', 'human',
#        'elephant', 'bear', 'tiger', 'dog', 'deer', 'mouse', 'cow',
#        'eagle', 'elephant', 'bear', 'pigeon', 'cow', 'chicken', 'cow',
#        'monkey', 'rabbit', 'cat', 'human', 'monkey', 'bear', 'cat', 'dog',
#        'wolf', 'chicken', 'pigeon', 'deer', 'eagle', 'wolf', 'sheep',
#        'chicken', 'lion', 'dog', 'panda', 'deer', 'monkey', 'human',
#        'wolf', 'cat', 'cat', 'bear', 'cat', 'eagle', 'mouse', 'elephant',
#        'panda', 'wolf', 'dog', 'chicken', 'human', 'monkey', 'sheep',
#        'monkey', 'sheep', 'rabbit', 'chicken', 'dog', 'human', 'deer',
#        'lion', 'dog', 'monkey', 'chicken', 'duck', 'bear', 'pigeon',
#        'cat', 'bear', 'cat', 'deer', 'mouse', 'dog', 'cow', 'rabbit',
#        'rabbit', 'monkey', 'cat', 'tiger', 'monkey', 'elephant', 'lion',
#        'duck', 'mouse', 'dog', 'mouse', 'panda', 'duck', 'sheep', 'deer',
#        'dog', 'mouse', 'cow', 'elephant', 'eagle', 'wolf', 'bear',
#        'eagle', 'panda', 'bear', 'pigeon', 'wolf', 'monkey', 'cat',
#        'sheep', 'pigeon', 'mouse', 'dog', 'pigeon', 'mouse', 'eagle',
#        'monkey', 'human', 'panda', 'human', 'rabbit', 'cow', 'tiger',
#        'sheep', 'lion', 'lion', 'eagle', 'lion', 'chicken', 'chicken',
#        'mouse', 'pigeon', 'panda', 'rabbit', 'elephant', 'tiger', 'tiger',
#        'duck', 'cat', 'chicken', 'panda', 'duck', 'rabbit', 'human',
#        'chicken', 'human', 'monkey', 'pigeon', 'deer', 'dog', 'human',
#        'mouse', 'deer', 'mouse', 'wolf', 'human', 'human', 'monkey',
#        'cat', 'dog', 'chicken', 'panda', 'pigeon', 'eagle', 'wolf',
#        'elephant', 'pigeon', 'duck', 'cat', 'panda', 'tiger', 'pigeon',
#        'cow', 'duck', 'eagle', 'tiger', 'sheep', 'wolf', 'eagle',
#        'monkey', 'elephant', 'lion', 'cat', 'mouse', 'cat', 'cow', 'bear',
#        'tiger', 'tiger', 'duck', 'lion', 'pigeon', 'human', 'dog', 'dog',
#        'human', 'cat', 'chicken', 'panda', 'pigeon', 'elephant', 'dog',
#        'cat', 'dog', 'cow'], dtype='<U8')

# %%
y_test_val = le.transform(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-cee8ad3845ba> in <module>
# ----> 1 y_test_val = le.transform(y_test)
#
# NameError: name 'le' is not defined

# %%
cr = sklearn.metrics.classification_report(y_test_val,y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-a1f574cce1ca> in <module>
# ----> 1 cr = sklearn.metrics.classification_report(y_test_val,y_pred,output_dict=True)
#       2 pd.DataFrame(cr).T
#
# NameError: name 'y_test_val' is not defined

# %% [markdown]
# ## Grid Search
# - Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = Pipeline([
    ('grascale',rgb2gray_transform()),
    ('hogtransform',hogtransformer()),
    ('scale',StandardScaler()),
    ('sgd',SGDClassifier())
])

# %%
param_grid = [
    {
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['optimal'] 
    },
    {
    
        'hogtransform__orientations' : [7.8,9,10],
        'hogtransform__pixels_per_cell' : [(7,7),(8,8),(9,9)],
        'hogtransform__cells_per_block' : [(2,2),(3,3)],
        'sgd__loss' : ['hinge','squared_hinge','perceptron'],
        'sgd__learning_rate': ['adaptive'],
        'sgd__eta0':[0.001,0.01]
    },
]

# %%
model_grid = GridSearchCV(estimator,
                          param_grid=param_grid,scoring='accuracy',
                          n_jobs=1,cv=2,verbose=2)

# %%
model_grid.fit(x_train,y_train)
# Out:
# Fitting 2 folds for each of 162 candidates, totalling 324 fits
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 292, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "C:\Users\dell\anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-30-00c9e67f5a53>", line 20, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-30-00c9e67f5a53>", line 20, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-30-00c9e67f5a53>", line 14, in local_hog
#     hog_features= skimage.feature.hog(img,orientations=self.orientations,
#   File "C:\Users\dell\anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.2s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   6.4s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   6.6s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.4s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.2s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   6.4s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   6.2s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   5.2s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   5.5s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   5.3s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   5.2s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.2s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.4s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   3.5s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   3.5s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   3.6s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   3.6s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   3.5s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   3.8s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   6.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   6.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.0s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.3s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.9s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   6.0s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   5.5s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   5.6s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   5.8s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   5.5s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.2s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.3s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   3.5s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   3.5s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   3.7s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   3.6s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   3.8s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   3.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 292, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "C:\Users\dell\anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-30-00c9e67f5a53>", line 20, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-30-00c9e67f5a53>", line 20, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-30-00c9e67f5a53>", line 14, in local_hog
#     hog_features= skimage.feature.hog(img,orientations=self.orientations,
#   File "C:\Users\dell\anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   6.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   6.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.4s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   6.3s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   6.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   5.2s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   5.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   5.3s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   3.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   3.4s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   3.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   3.4s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   3.5s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   3.4s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   6.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=hinge, total=   6.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.5s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   6.5s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   6.9s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   6.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   5.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=hinge, total=   5.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   5.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   5.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   5.5s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   3.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=hinge, total=   3.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   3.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=squared_hinge, total=   3.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   3.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__learning_rate=optimal, sgd__loss=perceptron, total=   3.7s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 330, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 292, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "C:\Users\dell\anaconda3\lib\site-packages\joblib\memory.py", line 352, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\pipeline.py", line 740, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "C:\Users\dell\anaconda3\lib\site-packages\sklearn\base.py", line 693, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "<ipython-input-30-00c9e67f5a53>", line 20, in transform
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-30-00c9e67f5a53>", line 20, in <listcomp>
#     hfeatures = np.array([local_hog(x) for x in X])
#   File "<ipython-input-30-00c9e67f5a53>", line 14, in local_hog
#     hog_features= skimage.feature.hog(img,orientations=self.orientations,
#   File "C:\Users\dell\anaconda3\lib\site-packages\skimage\feature\_hog.py", line 226, in hog
#     orientation_histogram = np.zeros((n_cells_row, n_cells_col, orientations))
# TypeError: 'float' object cannot be interpreted as an integer
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   0.1s
# [CV] hogtransform__cells_per_block=(2, 2), hogtransform__orientations=7.8, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# ...
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   6.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=17.5min
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=9, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   6.9s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=  13.4s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=  12.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=  12.3s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=  12.3s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=  12.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=  12.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge, total=  13.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge, total=  13.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=  13.0s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=  13.5s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=  13.4s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(7, 7), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=  13.4s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   9.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=  10.3s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   9.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   9.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   9.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   9.9s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge, total=  10.9s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge, total=  10.9s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=  10.6s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=  10.7s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=  10.8s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(8, 8), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=  10.9s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   5.9s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   5.9s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   5.2s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   5.2s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   5.5s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.001, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   5.5s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   6.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=hinge, total=   6.4s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   6.3s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=squared_hinge, total=   6.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   6.1s
# [CV] hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron
# [CV]  hogtransform__cells_per_block=(3, 3), hogtransform__orientations=10, hogtransform__pixels_per_cell=(9, 9), sgd__eta0=0.01, sgd__learning_rate=adaptive, sgd__loss=perceptron, total=   6.2s
# [Parallel(n_jobs=1)]: Done 324 out of 324 | elapsed: 44.4min finished
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('grascale', rgb2gray_transform()),
#                                        ('hogtransform', hogtransformer()),
#                                        ('scale', StandardScaler()),
#                                        ('sgd', SGDClassifier())]),
#              n_jobs=1,
#              param_grid=[{'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__learning_rate': ['optimal'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']},
#                          {'hogtransform__cells_per_block': [(2, 2), (3, 3)],
#                           'hogtransform__orientations': [7.8, 9, 10],
#                           'hogtransform__pixels_per_cell': [(7, 7), (8, 8),
#                                                             (9, 9)],
#                           'sgd__eta0': [0.001, 0.01],
#                           'sgd__learning_rate': ['adaptive'],
#                           'sgd__loss': ['hinge', 'squared_hinge',
#                                         'perceptron']}],
#              scoring='accuracy', verbose=2)

# %%
model_grid.best_params_
# Out:
# {'hogtransform__cells_per_block': (2, 2),
#  'hogtransform__orientations': 10,
#  'hogtransform__pixels_per_cell': (8, 8),
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge'}

# %%
model_grid.best_score_
# Out:
# 0.7021275494969741

# %%
model_best = model_grid.best_estimator_

# %%
y_pred = model_best.predict(x_test)

# %%
cr = sklearn.metrics.classification_report(y_test,y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
# C:\Users\Srikanth\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.818182  0.900000  0.857143   20.000000
# cat            0.857143  0.750000  0.800000   32.000000
# chicken        0.782609  0.900000  0.837209   20.000000
# cow            0.631579  0.571429  0.600000   21.000000
# deer           0.760000  0.904762  0.826087   21.000000
# dog            0.625000  0.769231  0.689655   26.000000
# duck           0.705882  0.571429  0.631579   21.000000
# eagle          0.521739  0.600000  0.558140   20.000000
# elephant       0.875000  0.700000  0.777778   20.000000
# human          0.950000  0.950000  0.950000   20.000000
# lion           0.736842  0.700000  0.717949   20.000000
# monkey         0.782609  0.900000  0.837209   20.000000
# mouse          0.666667  0.800000  0.727273   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.880000  0.916667  0.897959   24.000000
# pigeon         0.777778  0.608696  0.682927   23.000000
# rabbit         0.833333  0.500000  0.625000   20.000000
# sheep          0.440000  0.550000  0.488889   20.000000
# tiger          0.869565  0.869565  0.869565   23.000000
# wolf           0.833333  0.750000  0.789474   20.000000
# accuracy       0.747573  0.747573  0.747573    0.747573
# macro avg      0.717363  0.710589  0.708192  412.000000
# weighted avg   0.756166  0.747573  0.745926  412.000000

# %%
# save the model
pickle.dump(model_best,open('dsa_model_best.pickle','wb'))

# %% [markdown]
# ## Make Pipeline
#
#     {'hogtransform__cells_per_block': (2, 2),
#      'hogtransform__orientations': 10,
#      'hogtransform__pixels_per_cell': (8, 8),
#      'sgd__learning_rate': 'optimal',
#      'sgd__loss': 'hinge'}

# %%
from sklearn.pipeline import make_pipeline

# %%
pipeline1 = make_pipeline(rgb2gray_transform(),
                            hogtransformer(orientations=10,
                                           pixels_per_cell=(8,8),
                                           cells_per_block=(2,2)))

# %%
feature_vector = pipeline1.fit_transform(x_train)

# %%
# standard scaler
scalar = StandardScaler()
transformed_xtrain = scalar.fit_transform(feature_vector)

# %%
model = SGDClassifier(learning_rate='optimal',loss='hinge',alpha=0.01,early_stopping=True)

# %%
model.fit(transformed_xtrain,y_train)
# Out:
# SGDClassifier(alpha=0.01, early_stopping=True)

# %%
# evaluate
feature_vector = pipeline1.fit_transform(x_test)
transformed_x = scalar.transform(feature_vector)
y_pred_test = model.predict(transformed_x)

# %%
cr = pd.DataFrame(metrics.classification_report(y_test,y_pred_test,output_dict=True)).T
cr
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.705882  0.600000  0.648649   20.000000
# cat            0.794118  0.843750  0.818182   32.000000
# chicken        0.818182  0.900000  0.857143   20.000000
# cow            0.809524  0.809524  0.809524   21.000000
# deer           0.909091  0.952381  0.930233   21.000000
# dog            0.472222  0.653846  0.548387   26.000000
# duck           0.695652  0.761905  0.727273   21.000000
# eagle          0.733333  0.550000  0.628571   20.000000
# elephant       0.789474  0.750000  0.769231   20.000000
# human          0.950000  0.950000  0.950000   20.000000
# lion           0.652174  0.750000  0.697674   20.000000
# monkey         0.608696  0.700000  0.651163   20.000000
# mouse          0.652174  0.750000  0.697674   20.000000
# natural        0.000000  0.000000  0.000000    1.000000
# panda          0.916667  0.916667  0.916667   24.000000
# pigeon         0.678571  0.826087  0.745098   23.000000
# rabbit         0.846154  0.550000  0.666667   20.000000
# sheep          0.714286  0.500000  0.588235   20.000000
# tiger          1.000000  0.739130  0.850000   23.000000
# wolf           0.833333  0.750000  0.789474   20.000000
# accuracy       0.752427  0.752427  0.752427    0.752427
# macro avg      0.728977  0.712664  0.714492  412.000000
# weighted avg   0.764733  0.752427  0.752001  412.000000

# %%
# save models for flask app
pickle.dump(model,open('dsa_image_classification_sgd.pickle','wb'))

# %%
pickle.dump(scalar,open('dsa_scaler.pickle','wb'))

# %% [markdown]
# # Output Analysis

# %%
model_p = pickle.load(open('dsa_model_best.pickle','rb'))

# %%
model_p.get_params()
# Out:
# {'memory': None,
#  'steps': [('grascale', rgb2gray_transform()),
#   ('hogtransform',
#    hogtransformer(cells_per_block=(2, 2), orientations=8, pixels_per_cell=(10, 10))),
#   ('scale', StandardScaler()),
#   ('sgd', SGDClassifier(eta0=0.001))],
#  'verbose': False,
#  'grascale': rgb2gray_transform(),
#  'hogtransform': hogtransformer(cells_per_block=(2, 2), orientations=8, pixels_per_cell=(10, 10)),
#  'scale': StandardScaler(),
#  'sgd': SGDClassifier(eta0=0.001),
#  'hogtransform__cells_per_block': (2, 2),
#  'hogtransform__orientations': 8,
#  'hogtransform__pixels_per_cell': (10, 10),
#  'scale__copy': True,
#  'scale__with_mean': True,
#  'scale__with_std': True,
#  'sgd__alpha': 0.0001,
#  'sgd__average': False,
#  'sgd__class_weight': None,
#  'sgd__early_stopping': False,
#  'sgd__epsilon': 0.1,
#  'sgd__eta0': 0.001,
#  'sgd__fit_intercept': True,
#  'sgd__l1_ratio': 0.15,
#  'sgd__learning_rate': 'optimal',
#  'sgd__loss': 'hinge',
#  'sgd__max_iter': 1000,
#  'sgd__n_iter_no_change': 5,
#  'sgd__n_jobs': None,
#  'sgd__penalty': 'l2',
#  'sgd__power_t': 0.5,
#  'sgd__random_state': None,
#  'sgd__shuffle': True,
#  'sgd__tol': 0.001,
#  'sgd__validation_fraction': 0.1,
#  'sgd__verbose': 0,
#  'sgd__warm_start': False}

# %%
img_test= skimage.io.imread('tiger_test.jpg')
plt.imshow(img_test)

# %%
# image size is 80 x 80
img_resize = skimage.transform.resize(img_test,(80,80))
# rescale into 255
img_rescale = np.array(255*img_resize).astype(np.uint8)
plt.imshow(img_rescale)

# %%
# pass to pipeline model
img_reshape = img_rescale.reshape(-1,80,80,3)
print(img_reshape.shape)
result = model_pipeline.predict(img_reshape)
print(result)
# Out:
# (1, 80, 80, 3)
# [5]

# %%
# Descision Function
distance = model_pipeline.decision_function(img_reshape)[0]
print(distance)
# Out:
# [ 5.75370712 12.24500513  5.76864729 12.20746737  2.7388824  19.30485679
#   7.77682698  3.7492711   8.78288887 10.11721968 16.26141015 13.24395185
#  17.28262812 -0.30971381  1.72096413  0.71980935 18.29393238 15.27077942
#  13.23525647  5.75854397]

# %%
labels = list(data['labels'])
labels.sort()
print(labels)
# Out:
# ['bear', 'cat', 'chicken', 'cow', 'deer', 'dog', 'duck', 'eagle', 'elephant', 'human', 'lion', 'monkey', 'mouse', 'natural', 'panda', 'pigeon', 'rabbit', 'sheep', 'tiger', 'wolf']

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,distance)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# confidence score
mean_distance = distance.mean()
std_distance = distance.std()
z = (distance - mean_distance)/std_distance
z
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])

# %%
mean_distance
# Out:
# 9.496116738372246

# %%
std_distance
# Out:
# 5.976331358171906

# %%
from scipy import stats

# %%
dist = stats.t

# %%
dist.cdf(2.21719813,19)
# Out:
# 0.9804985267531022

# %%
dof = len(z) - 1
pvalues = [dist.cdf(zval,dof) for zval in z]
print(pvalues)
# Out:
# [0.2693157161111511, 0.6746184285442451, 0.2701187789365209, 0.6724013008095282, 0.13613339380733908, 0.94140393774905, 0.38835184849219784, 0.1741646039671521, 0.4531285822198086, 0.5408418151202851, 0.8641432492347143, 0.7309755940591313, 0.8959089406248415, 0.05864698735263532, 0.10440945435151623, 0.07916370072656952, 0.9213186651894776, 0.8269722933653654, 0.7305086321415764, 0.2695755643050099]

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,pvalues)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
import scipy

# %%
aa = scipy.special.softmax(z)

# %%
plt.figure(figsize=(10,6))
plt.barh(labels,aa)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
import scipy

# %%
scipy.stats.zscore(distance)
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])

# %%
z
# Out:
# array([-0.62620517,  0.45996251, -0.62370528,  0.45368144, -1.13066594,
#         1.64126443, -0.28768314, -0.9616009 , -0.11934209,  0.10392713,
#         1.13201444,  0.627113  ,  1.30289151, -1.64077759, -1.30099088,
#        -1.46851084,  1.47210975,  0.96625544,  0.62565803, -0.62539584])
